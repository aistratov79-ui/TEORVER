# %% [markdown]
# # Комбинаторика

# %%
import scipy.special as sc
from itertools import product

# %% [markdown]
# ## Задача 1.8
#
# > В конкурсе по 5 номинациям участвуют 10 кино-фильмов. Сколько существует вариантов распределения призов, если по каждой номинации установлены:
# > а) различные призы; б) одинаковые призы?
#
# * Рассмотрим событие $A$ – по каждой номинации установлены различные призы

# %%
n=10
k=5
a=n**k
b=sc.comb(n,k, repetition=True)
print("a)",a)
# Out:
# a) 100000

# %% [markdown]
# * Рассмотрим событие $B$ – по каждой номинации установлены одинаковые призы

# %%
print("b)",b)
# Out:
# b) 2002.0

# %% [markdown]
# ## Задача 1.9
# > Сколько существует семизначных чисел, состоящих из цифр 4, 5 и 6, в которых цифра 4 повторяется 3 раза, а цифры 5 и 6 - по 2 раза?

# %%
print("Количество семизначных чисел :",sc.factorial(7)/(sc.factorial(3)*sc.factorial(2)*sc.factorial(2)))
# Out:
# Количество семизначных чисел : 210.0

# %% [markdown]
# ## Задача 1.10
# > Буквы Т, Е, И, Я, Р, О написаны на отдельных карточках. Ребенок берет карточки в случайном порядке и прикладывает одну к друтой: а) 3 карточки;
# > б) все 6 карточек. Какова вероятность того, что получится слово: а) «ТОР»; б) «ТЕОРИЯ»?

# %% [markdown]
# * Рассмотрим вероятность события $A$ – получится слово ТОР из 3 карточек

# %%
print("Вероятность события A равна:",round(1/sc.perm(6,3),4))
# Out:
# Вероятность события A равна: 0.0083

# %% [markdown]
# * Рассмотрим вероятность события $B$ – получится слово ТЕОРИЯ из 6 карточек

# %%
print("Вероятность события A равна:",round(1/sc.factorial(6),4))
# Out:
# Вероятность события A равна: 0.0014

# %% [markdown]
# ## Задача 1.11
# > Используя условие примера 1.10, найти вероятность того, что получится слово «АНАНАС», если на отдельных карточках написаны три буквы А, две буквы Н и одна буква С.

# %% [markdown]
# * Рассмотрим вероятность события $A$ – получится слово АНАНАС из 6 карточек

# %%
print("Вероятность события A равна:",round(1/(sc.factorial(6)/(sc.factorial(3)*sc.factorial(2)*sc.factorial(1))),4))
# Out:
# Вероятность события A равна: 0.0167

# %% [markdown]
# ## Задача 1.16

# %% [markdown]
# >За круглым столом рассаживаются 5 мужчин и 5 женщин. Найти вероятность того, что: а) никакие два лица одного пола не сядут рядом;
# >б) супруги сядут рядом, если эти мужчины и женщины образуют 5 супружеских пар.

# %% [markdown]
# * Рассмотрим вероятность события $A$ – никакие два лица одного пола не сядут рядом

# %%
print("Вероятность события A равна:",round(2*sc.factorial(5)**2/sc.factorial(10),4))
# Out:
# Вероятность события A равна: 0.0079

# %% [markdown]
# * Рассмотрим вероятность события $B$ – супруги сядут рядом, если эти мужчины и женщины образуют 5 супружеских пар.

# %%
print("Вероятность события B равна:",round(sc.factorial(5)*2**5/sc.factorial(10),4))
# Out:
# Вероятность события B равна: 0.0011

# %% [markdown]
# ## Задача 1.17

# %% [markdown]
# > В купейный вагон (9 купе по 4 места) семи пассажирам продано 7 билетов. Найти вероятности того, что пассажиры попали: а) в два купе;
# > б) в семь купе; в) в три купе.

# %% [markdown]
# * Рассмотрим вероятность события $A$ – пассажиры попали в два купе

# %%
result=(sc.comb(9,2)*sc.comb(8,7)/sc.comb(36,7))

# %%
print("Вероятность события A равна:",f"{result:.7f}")
# Out:
# Вероятность события A равна: 0.0000345

# %% [markdown]
# * Рассмотрим вероятность события $B$ – пассажиры попали в семь купе

# %%
result=(sc.comb(9,7)*4**7/sc.comb(36,7))

# %%
print("Вероятность события B равна:",f"{result:.7f}")
# Out:
# Вероятность события B равна: 0.0706572

# %% [markdown]
# * Рассмотрим вероятность события $C$ – пассажиры попали в три купе

# %%
result=(sc.comb(9, 3) * (6 * sc.comb(4, 4) * sc.comb(4, 2) * sc.comb(4, 1) +3 * sc.comb(4, 3) * sc.comb(4, 3) * sc.comb(4, 1)+ 3 * sc.comb(4, 3) * sc.comb(4, 2) * sc.comb(4, 2))/sc.comb(36,7))

# %%
print("Вероятность события C равна:",f"{result:.7f}")
# Out:
# Вероятность события C равна: 0.0077281

# %% [markdown]
# # Классическая и геометрическая вероятность

# %% [markdown]
# ## Задача 1.38

# %% [markdown]
# > Пятитомное собрание сочинений расположено на полке в случайном порядке. Какова вероятность того, что книги стоят слева направо в порядке нумерации томов (от 1 до 5)?

# %% [markdown]
# * Рассмотрим вероятность события $A$ – книги стоят слева направо в порядке нумерации томов (от 1 до 5)

# %%
print("Вероятность события A равна:",round(1/sc.factorial(5),4))
# Out:
# Вероятность события A равна: 0.0083

# %% [markdown]
# ## Задача 1.43

# %% [markdown]
# >Наудачу взятый телефонный номер состоит из 5 цифр.
# Какова вероятность того, что в нем все цифры: а) различные;б) одинаковые; в) нечетные? Известно, что номер телефона не начинается с цифры ноль.

# %%
n=9*10**4
m_a=9*sc.perm(9,4)
a=m_a/n
m_b=9
b=9/n
c=round(5**5/n,4)

# %% [markdown]
# * Рассмотрим вероятность события $A$ – все цифры различные

# %%
print("Вероятность события A равна:",a)
# Out:
# Вероятность события A равна: 0.3024

# %% [markdown]
# * Рассмотрим вероятность события $B$ – все цифры  одинаковые

# %%
print("Вероятность события B равна:",b)
# Out:
# Вероятность события B равна: 0.0001

# %% [markdown]
# * Рассмотрим вероятность события $C$ – все цифры нечетные

# %%
print("Вероятность события C равна:",c)
# Out:
# Вероятность события C равна: 0.0347

# %% [markdown]
# ## Задача 1.48

# %% [markdown]
# >В старинной игре в кости необходимо было для выигрыша получить при бросании трех игральных костей сумму очков, превосходящую 10. Найти вероятности: а) выпадения ll очков; б) выигрыша.

# %%
combinat=(list(product(range(1,7),repeat=3)))
n=len(combinat)
a=len([elem for elem in combinat if sum(elem)==11 ])
p_A=a/n
b=len([elem for elem in combinat if sum(elem)>10 ])
p_B=b/n

# %% [markdown]
# * Рассмотрим вероятность события $A$ – выпало ll очков

# %%
print("Вероятность события A равна:",round(p_A,4))
# Out:
# Вероятность события A равна: 0.125

# %% [markdown]
# * Рассмотрим вероятность события $B$ – мы выйграли

# %%
print("Вероятность события B равна:",round(p_B,4))
# Out:
# Вероятность события B равна: 0.5
